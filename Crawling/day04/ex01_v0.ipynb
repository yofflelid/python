# %%
# Chap 15.riss.kr 에서 특정 키워드로 논문 / 학술 자료 검색하기

#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time

# %%
#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
#print("=" *100)
#print(" 이 크롤러는 서울시민 사이트의 논문 및 학술자료 수집용 웹크롤러입니다.")
#print("=" *100)
#query_txt = input('1.수집할 자료의 키워드는 무엇입니까?: ')

# %%
#Step 3. 수집된 데이터를 저장할 파일 이름 입력 받기
f_dir = input("2.파일을 저장할 폴더명만 쓰세요(기본값:c:\\py_temp\\):")
if f_dir == '' :
    f_dir="c:\\py_temp\\"

# %%
#Step 4. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)

url = 'https://eungdapso.seoul.go.kr/main.do'
driver.get(url)
driver.maximize_window()
time.sleep(2)

# %%
#Step 5. 자동으로 검색어 입력 후 조회하기
#element = driver.find_element(By.ID,'query')
#element.send_keys(query_txt)
#element.send_keys("\n")


#link = soup.find('div','my_current_count_box').find('a')['href']

#//*[@id="content"]/div[2]/a/div

# %%
#Step 6.학위 논문 선택하기
#driver.find_element(By.LINK_TEXT,'학위논문').click()
#time.sleep(2)



driver.find_element(By.XPATH,'//*[@id="content"]/div[2]/a/div').click()
time.sleep(2)

# %%
# 시장에게 바란다 접속 완료

# %%
#Step 7.Beautiful Soup 로 본문 내용만 추출하기
from bs4 import BeautifulSoup
html_1 = driver.page_source
soup_1 = BeautifulSoup(html_1, 'html.parser')

# %%
#Step 8. 총 검색 건수를 보여주고 수집할 건수 입력 받기
import math
total_cnt = soup_1.find('div','rp_lkment').find('span','rplk_count').get_text()
print( '총 %s 의 민원신청이 검색되었습니다' %(total_cnt))
cnt = int(input('이 중에서 몇 건을 수집하시겠습니까?: '))
page_cnt = math.ceil(cnt / 10)
print('%s 건의 데이터를 수집하기 위해 %s 페이지의 게시물을 조회합니다.' %(cnt,page_cnt))
print("\n")
# Out:
# 총 340건 의 민원신청이 검색되었습니다
# 10 건의 데이터를 수집하기 위해 1 페이지의 게시물을 조회합니다.

# %%
for i in range(1,11):

    xpath = '//*[@id="content"]/div[2]/div[4]/table/tbody/tr[%s]/td[2]/div/a' % i
    
    driver.find_element(By.XPATH, xpath).click()

    time.sleep(2)

    # 여기서 상세페이지 데이터 수집

    driver.back()   # 목록으로 돌아가기
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[9], line 5
#       1 for i in range(1,11):
#       3     xpath = '//*[@id="content"]/div[2]/div[4]/table/tbody/tr[%s]/td[2]/div/a' % i
# ----> 5     driver.find_element(By.XPATH, xpath).click()
#       7     time.sleep(2)
#
# File c:\Users\itwill\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:816, in WebDriver.find_element(self, by, value)
#     813         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     814     return elements[0]
# --> 816 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\itwill\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:446, in WebDriver.execute(self, driver_command, params)
#     443 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     445 if response:
# --> 446     self.error_handler.check_response(response)
#     447     response["value"] = self._unwrap_value(response.get("value", None))
#     448     return response
#
# File c:\Users\itwill\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="content"]/div[2]/div[4]/table/tbody/tr[2]/td[2]/div/a"}
#   (Session info: chrome=145.0.7632.117); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff7f111aa55
# 	0x7ff7f0e78630
# 	0x7ff7f0c0d75d
# 	0x7ff7f0c6862e
# 	0x7ff7f0c6893c
# 	0x7ff7f0cb8d87
# 	0x7ff7f0cb591c
# 	0x7ff7f0c59098
# 	0x7ff7f0c59f83
# 	0x7ff7f1147810
# 	0x7ff7f1141afd
# 	0x7ff7f1162c1a
# 	0x7ff7f0e93345
# 	0x7ff7f0e9b81c
# 	0x7ff7f0e81924
# 	0x7ff7f0e81ad6
# 	0x7ff7f0e67e47
# 	0x7ff9ee9ae8d7
# 	0x7ff9ef70c40c

# %%
print(len(content_list))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 print(len(content_list))
#
# NameError: name 'content_list' is not defined

# %%
for i in content_list:
    title = i.get_text().strip()
    print(title)
# Out:
# 시장정비사업 효력상실고시 요청
# 원효로3가 1구역전체 권리산정일 지정
# 신림봉천 터널공사를 10년 넘게 하고 있는데 언제 개통되나요?
# 시민들의 포근한 밤 만들기 프로젝트....
# 압구정-과천-위례선 노선에서  양재IC (AI역) 역 확정 요청
# 난임 지원금 신청 편의 문제
# 502번 노선단축 필요성
# 안녕하십니까? 의료비 혜택받고 싶습니다.
# 세운지구(을지로 인쇄골목) 도심 공동화 방지를 위한 공실 활용 및 창업 생태계 조성 정책 제안
# 보라매공원 건의사항

# %%
for i in content_list:
    link = i.find('a')['href']
    print(link)
# Out:
# javascript:onView('Ti5rXV1s5rL_GD4mUoSyv_qEz4zHQgeIWJi7rxq2FmKSJ9OsIow0962NYr_qx8uBp8qiQcFQNN_zDTJjZi4o2873Fy5f2uZxkF-MtmsMFJWiuJxrpDiZ-gT8AFQWwPBaADQJ9g7BRckbiH3ANL4H7ntUrOmli4wdBQPpKv3lgzo');
# javascript:onView('VsZPYbeaEQXGMpYUK7eSPC5kQ_U7AZ0jZgyKAp2VWcVDUPqKKxQtNW_FQ588fWebuDi4NUADIWc2J_OHcA4bgzIK4msaPlcfF4dBUGCGgU0Qv1lZebBQOPYHhsXw12O3JpyLvQsBsHfEY6TMVb81ad_yLOP1WFUnSEln802xXhE');
# javascript:onView('Sa8RdGThIaKlB9EInp4H8-tCEw7ABFqrSAOW9sW8lYWxUHX07gZ4FtARt15rssxw75rFo0UyLXdeBu1oI9860b-DDkJFWXv04zHk-UhHTBD6nL-HXB88hjBS-mrg0HeC5R7DvtcULYohvKQUNWGhxmBjrW2hCDaw7YbQhh6MMGc');
# javascript:onView('YTUN5rSDr_VKsSVSKSQk6fSyRYJfNTVCxr0IjW1uyIUxWNCj00kcSprQsiJz-8PXBPJG9vOtQyYjHuwL49kLM3I0TCze3vNNSb72V2jIPhe2dru_vnnmKc1w4j7oRGw1FefVwcC9FgiOxu-GpUuFzEoq39DAFVBHocyfbj9dcF4');
# javascript:onView('Uk1_PP5qdmxCJ9Bdk3qOC1CKPw06CyuGYmhMXQ_JmmPO4WiHGaDaGt3xSm8odmOE6jLrszBJ5t8FoWiEvrXvg6Yec4EaEXyk93-j9h7LoizGGynCeUVc9T9Du-u6wykmYutd-kRB2X0-bv3S6rAEhRcnLKzUatMUcciYlCT_u4Y');
# javascript:onView('Qz0gpDs9wpTmOuFcOlprWMVsrMKyKuhRKt6d-2vCjGJfqv-GfIV1T-uiPHDFEts-TC51lcKzeFQGwtlHtdHyvYTZIzNg2SXS8xGuyEy4SIX60ADJeAU0_Go_VjXpzqsJ0B-70dc211fXqyjbd_hrr16Aax7YYa7lOezgMSXwL6s');
# javascript:onView('Df2dkMOgn-KNClQdw0pfOL2HfJcDeGg-ixn_MyDdYtkqkmLPJ_tL06Oly8MJDqT1jo-b81TZJDjMgJg5oTLEs3-0Pfmr2XUnA5Cg3AQzcxnJlMlemKV3tQN2YoR5SkbCnh3uRi8PQTdXueDMBHVHaeoyqzVLTn2RqPcgU2cFy4E');
# javascript:onView('Rr2jInsPu9NniNY3soUhlaXHhS0nHLV9nghCZ_Wc_GXfRJpAr5YxQKOkEQeztEn3Owm0UVfjY0-hteGkn6qYpchiEb1Ut97pY7f1YD47QaEc0bQ-8c31eIcWqib1RUw63BiSMnNoM_EWuT9M_6B8TmMBvUzMpBNQ5zYY3iOqwx8');
# javascript:onView('Zi7qf_6br-dGbYeqVj_7JaWO2_hzwkhNWa5AMYa4-19AV3hG0-i36OaFqZTd0_5lDFCehgtL04N99xlAnLgpXOmq7DBSvclTiT5DezeDcGAK2GMDgQ1g4OrGEJL1ySRoGp8eJiGKJXCQqXvy8F-wT1XRezipmXRJ8H8CFjndg-Y');
# javascript:onView('M2EhJjGz1gtnWxRDv5Alw7SvR49FRnWEEaXtEf6buZHyqi3Q63wT6ogpJ-sct0HkrfYUHy1H3AcUNhl4yAw1cdwg0qAvG4fN5fAcJTeCsMEoJ1JoIyk1NYq_Gi1fU8ScoBaILsooaDOYbRIqKL7fab3nxOyeP_B_A0bQDlUwn24');

# %%
#link = content_list[0].find('a')
#driver.execute_script("arguments[0].click();", link)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 2
#       1 link = content_list[0].find('a')
# ----> 2 driver.execute_script("arguments[0].click();", link)
#
# File c:\Users\itwill\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:532, in WebDriver.execute_script(self, script, *args)
#     529 converted_args = list(args)
#     530 command = Command.W3C_EXECUTE_SCRIPT
# --> 532 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File c:\Users\itwill\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:443, in WebDriver.execute(self, driver_command, params)
#     440     elif "sessionId" not in params:
#     441         params["sessionId"] = self.session_id
# --> 443 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     445 if response:
#     446     self.error_handler.check_response(response)
#
# File c:\Users\itwill\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:403, in RemoteConnection.execute(self, command, params)
#     401     for word in substitute_params:
#     402         del params[word]
# --> 403 data = utils.dump_json(params)
#     404 url = f"{self._client_config.remote_server_addr}{path}"
#     405 trimmed = self._trim_large_entries(params)
#
# File c:\Users\itwill\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\utils.py:23, in dump_json(json_struct)
#      22 def dump_json(json_struct: Any) -> str:
# ---> 23     return json.dumps(json_struct)
#
# File c:\Users\itwill\AppData\Local\Programs\Python\Python313\Lib\json\__init__.py:231, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     226 # cached encoder
#     227 if (not skipkeys and ensure_ascii and
#     228     check_circular and allow_nan and
#     229     cls is None and indent is None and separators is None and
#     230     default is None and not sort_keys and not kw):
# --> 231     return _default_encoder.encode(obj)
#     232 if cls is None:
#     233     cls = JSONEncoder
#
# File c:\Users\itwill\AppData\Local\Programs\Python\Python313\Lib\json\encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File c:\Users\itwill\AppData\Local\Programs\Python\Python313\Lib\json\encoder.py:261, in JSONEncoder.iterencode(self, o, _one_shot)
#     256 else:
#     257     _iterencode = _make_iterencode(
#     258         markers, self.default, _encoder, indent, floatstr,
#     259         self.key_separator, self.item_separator, self.sort_keys,
#     260         self.skipkeys, _one_shot)
# --> 261 return _iterencode(o, 0)
#
# File c:\Users\itwill\AppData\Local\Programs\Python\Python313\Lib\json\encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)    178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type Tag is not JSON serializable

# %% [markdown]
# 여기까지는 잘 되는듯?

# %%
#Step 9. 데이터 수집하기
no2=[] # 게시글 번호 컬럼
title2=[ ] # 민원신청 제목 
date2=[ ] # 게시글 날짜 컬럼
contents2=[] # 상담내용
full_url2=[] # 논문 원본 URL

no = 1 # 게시글 번호 초기값

for a in range(1,page_cnt+1) :
    print("\n")
    print("%s 페이지 내용 수집 시작합니다 =======================" %a)

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    content_list = soup.find('div','rp_tb_wrap default_skin complaint_mayor_hope_list').find_all('div','rp_inlink_item')

    for i in content_list:
        # 여기서 바로 들어 가야겠네?? 아니면 제목 뽑고 들어가거나 ?? 

        # 민원신청 제목 체크하기
        try:
            title=i.find('div','rp_inlink_item').get_text().strip()
        except :
            continue
        else :
            # 1.게시글 번호
            print("\n")
            print("%s 번째 정보를 추출하고 있습니다============" %no)
            no2.append(no)
            print("1.번호 : %s" %no)

            # 2. 민원신청 제목
            title2.append(title.strip())
            print("2.제목 : %s" %title.strip())

            # 3. 민원목록 안의 상세 내역에서 추출할 수 있음.
            url_1 = i.find('div','rp_inlink_item').find('a')['href']
            full_url = 'http://eungdapso.seoul.go.kr/'+url_1
            full_url2.append(full_url)
            time.sleep(1)
            driver.get(full_url)

            html_1 = driver.page_source
            soup_1 = BeautifulSoup(html_1, 'html.parser')

            # 4. 공개일 
            try :
                date_1 =i.find('div','sclinkage_else').find_all('span')
                date_2 = date_1[1].get_text().strip()
            except :
                date_2='공개일가 없습니다'
                date2.append(date_2)
                print("4.공개일 : %s" %date_2)
            else :
                date2.append(date_2)
                print("4.공개일 : %s" %date_2)

            # 5. 상담내용
            try :
                cont=soup_1.find("div","res_hcell restd").find('div','restd_incont').get_text().replace("\n","").strip()
            except :
                cont='상담내용이 없습니다'
                contents2.append(cont)
                print("5.상담내용 : %s" %cont)
            else :
                contents2.append(cont)
                print("5.상담내용 : %s" %cont)



            driver.back() # 이전 페이지로 돌아가기

            time.sleep(2)

            no += 1

            if no > cnt :
                break

    a += 1
    b = str(a)

    try :
        driver.find_element(By.LINK_TEXT ,'%s' %b).click()
    except :
        driver.find_element(By.LINK_TEXT,'다음 페이지로').click()

print("요청하신 작업이 모두 완료되었습니다")
# Out:
# 1 페이지 내용 수집 시작합니다 =======================
#
#
# 2 페이지 내용 수집 시작합니다 =======================
# 요청하신 작업이 모두 완료되었습니다

# %%
driver.get(full_url)
print(driver.title)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 driver.get(full_url)
#       2 print(driver.title)
#
# NameError: name 'full_url' is not defined

# %%
# Step 10. 수집된 데이터를 xlsx와 csv 형태로 저장하기
# 현재 날짜와 시간으로 폴더 만들고 파일 이름 설정하기
import os

n = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' %(n.tm_year, n.tm_mon, n.tm_mday, n.tm_hour, n.tm_min, n.tm_sec)

os.makedirs(f_dir+'RISS'+'-'+s+'-'+'학위논문')

fc_name = f_dir+'RISS'+'-'+s+'-'+'학위논문'+'\\'+'RISS'+'-'+s+'-'+'학위논문'+'.csv'
fx_name = f_dir+'RISS'+'-'+s+'-'+'학위논문'+'\\'+'RISS'+'-'+s+'-'+'학위논문'+'.xlsx'

# 데이터 프레임 생성 후 xlsx, csv 형식으로 저장하기
import pandas as pd

df = pd.DataFrame()
df['번호']=no2
df['제목']=pd.Series(title2)
df['날짜']=pd.Series(date2)
df['상담내용']=pd.Series(contents2)

# xls 형태로 저장하기
df.to_excel(fx_name,index=False)

# csv 형태로 저장하기
df.to_csv(fc_name,index=False, encoding="utf-8-sig")

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
# Out:
# 요청하신 데이터 수집 작업이 정상적으로 완료되었습니다

# %% [markdown]
# 참고

# %%
#spans = i.find('p','etc').find_all('span')

#author = spans[0].text
#company = spans[1].text
#date = spans[2].text
#degree = spans[3].text

# %%
#1️⃣ 태그로 찾기
#find('div')
#2️⃣ class로 찾기
#find('span','writer')
#3️⃣ 여러개 찾고 인덱스로 구분
#find_all('span')[2]

# %%
            # 5. 상담내용 
#            try :
#                cont=soup_1.find("span","rp_indata").find('div','restd_incont').get_text().replace("\n","").strip()
#            except :
#                cont='상담내용이 없습니다'
#                contents2.append(cont)
#                print("5.상담내용 : %s" %cont)
#            else :
#                contents2.append(cont)
#                print("5.상담내용 : %s" %cont)
