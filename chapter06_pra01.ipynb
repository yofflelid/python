# %%
# Case 1 – 클라이언트 정보가 필요 없는 경우 
# Step 1. 필요한 모듈과 라이브러리를 로딩하고 검색어를 입력 받습니다 
from selenium import webdriver 
from selenium.webdriver.common.by import By 
from selenium.webdriver.common.keys import Keys 
from selenium.webdriver.chrome.service import Service 
from bs4 import BeautifulSoup 
import urllib.request 
import urllib.parse 
import time 
import math 
import os 
import random

# %%
#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다. 
print("=" *100) 
print(" 이 크롤러는 휴넷 사이트의 강의 자료 수집용 웹크롤러입니다.") 
print("=" *100) 
query_txt = input('1.수집할 자료의 키워드는 무엇입니까?(예: 파이썬): ') 

try : 
    
    cnt = int( input('2.수집할 건수는 총 몇건입니까?(기본값:10): ')) 
except ValueError : 
    
    
    cnt = 10 
    print('기본값인 10 건으로 수집을 진행합니다.') 
page_cnt = math.ceil( cnt / 12) 

f_dir=input('3.파일이 저장될 경로만 쓰세요(예: c:\\py_temp\\ ) : ') 
if f_dir =='' : 
    
    f_dir = "c:\\py_temp\\"
# Out:
# ====================================================================================================
#  이 크롤러는 휴넷 사이트의 강의 자료 수집용 웹크롤러입니다.
# ====================================================================================================

# %%
#Step 3. 크롬 드라이버 설정 및 웹 페이지 열기 
s = Service("c:/py_temp/chromedriver.exe") 
driver = webdriver.Chrome(service=s) 

url = 'https://www.hunet.co.kr/' 
driver.get(url) 
driver.maximize_window() 
time.sleep(3)

# %%
#Step 4. 자동으로 검색어 입력 후 조회하기 
element = driver.find_element(By.ID,'txtKeyword') 
driver.find_element(By.ID,'txtKeyword').click( ) 
element.send_keys(query_txt) 
element.send_keys("\n")

# %%
#Step 5. 사용자가 요청한 건수만큼 더보기 클릭하기 
for a in range(0,page_cnt) : 
    try : 
        driver.find_element(By.XPATH,'//*[@id="divEducationList"]/div/div[2]/div[5]/a[1]').click() 
        time.sleep(2) 
        try : 
            result = driver.switch_to.alert() 
            result.accept( ) 
        except : 
            continue 
    except : 
        print('페이지 이동이 끝났습니다. 이제 데이터를 수집하겠습니다') 
        break

# %%
# Step 6. 이미지 추출하여 저장하기  
file_no = 0                                 
count = 1 
img_src2=[]  # 이미지 원본 URL 주소 저장할 리스트 

n = time.localtime() 
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (n.tm_year, n.tm_mon, n.tm_mday, n.tm_hour, n.tm_min, n.tm_sec) 
img_dir = f_dir+s+'-'+query_txt 
os.makedirs(img_dir) 
os.chdir(img_dir) 

html = driver.page_source 
soup = BeautifulSoup(html, 'html.parser') 
img_src = soup.find('ul','vod_list').find_all('img') 

for i in img_src : 
    img_src1=i['src'] 
    img_src2.append(img_src1) 
    print(img_src1) 
    count += 1 
    if count > cnt : 
        break 
  
for i in range(0,len(img_src2)) : 
    file_no += 1  
    #이미지 파일에 한글 이름이 들어갈 경우 오류가 발생하므로 인코딩 지정해 주어야 함 
    urllib.request.urlretrieve(urllib.parse.quote(img_src2[i].encode('utf8'), '/:'),str(file_no)+'.jpg') 
  
    time.sleep(0.5)       
    print("%s 번째 이미지 저장중입니다=======" %file_no)
# Out:
# https://img.hunet.co.kr/files/Process/Course/Sample/2_와이드사이즈.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP21000(1).png
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP20399.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP14220.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP14214.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAC12244(2).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/쉽게-따라하는-엑셀-및-SQL-데이터-분석-with-ChatGPT_1(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAC10893(3).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP09369.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/직장인이-꼭!-알아야-할-AI-활용-시장-조사-및-데이터-분석_1(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP08358.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP23048.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP07272(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP01429.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP01122.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP92350(1).png
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP92079.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP92000.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP89947.png
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP89916(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP89917.png
# https://img.hunet.co.kr/files/Process/Course/Sample/341×187_HLSP89158.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP87208(2).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/41_HLSC84882.JPG
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP51082.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/341x187_파이썬-기초.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/[썸네일]341x187_머신러닝을-활용한-빅데이터-분석.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/[썸네일]341x187_R을-활용한-빅데이터-분석.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/341x187_SQL-활용.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP48798.png
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP81088(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP81072.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP80559(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP80564.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP79622(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP77578(3).png
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP76043.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP74480(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/[썸네일] HLSP74446.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP67913.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP69981.JPG
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP69006.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP68031.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP65303.JPG
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP65279.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP63101.JPG
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP60911.JPG
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP60105.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP59725.JPG
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP34379.png
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP42413.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP49960(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP41738.png
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP51671.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP42468.JPG
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP23367(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP13231(3).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP91565.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP91617.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP88946.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP81439.JPG
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP81423.JPG
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP81276.JPG
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP71767.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP36502.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP81069(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/33_HLSC75275.JPG
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP64172.JPG
# https://img.hunet.co.kr/files/Process/Course/Sample/HLSP80969.JPG
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP22330(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP25705.png
# https://img.hunet.co.kr/files/Process/Course/Sample/(AI시각화)썸네일_바이더북2.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP24768.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAC23359(1).png
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP22330(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP22331(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP21181.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP20394.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP20397.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP20395.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/실무에서-바로-쓰는-엑셀-업무-효율화_1(5).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP14219.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP14213.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAC13947(2).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/실무에서-바로-쓰는-엑셀-업무-효율화_1(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP09368.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/AI로-끝내는-앱-서비스-마케팅_1(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/노코드-마케팅-업무-자동화를-위한-AI-서비스-모음ZIP_1(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP09367.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP09366.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/341X187(26).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/341X187(25).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/55_HLAC07500.JPG
# https://img.hunet.co.kr/files/Process/Course/Sample/ai_341x187.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP07273(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP03065.jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP01420(1).jpg
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP01419.png
# https://img.hunet.co.kr/files/Process/Course/Sample/HLAP01201.png
# https://img.hunet.co.kr/files/Process/Course/Sample/51_HLAC00947.JPG
# 1 번째 이미지 저장중입니다=======
# 2 번째 이미지 저장중입니다=======
# 3 번째 이미지 저장중입니다=======
# 4 번째 이미지 저장중입니다=======
# 5 번째 이미지 저장중입니다=======
# 6 번째 이미지 저장중입니다=======
# 7 번째 이미지 저장중입니다=======
# 8 번째 이미지 저장중입니다=======
# 9 번째 이미지 저장중입니다=======
# 10 번째 이미지 저장중입니다=======
# 11 번째 이미지 저장중입니다=======
# 12 번째 이미지 저장중입니다=======
# 13 번째 이미지 저장중입니다=======
# 14 번째 이미지 저장중입니다=======
# 15 번째 이미지 저장중입니다=======
# 16 번째 이미지 저장중입니다=======
# 17 번째 이미지 저장중입니다=======
# 18 번째 이미지 저장중입니다=======
# 19 번째 이미지 저장중입니다=======
# 20 번째 이미지 저장중입니다=======
# 21 번째 이미지 저장중입니다=======
# 22 번째 이미지 저장중입니다=======
# 23 번째 이미지 저장중입니다=======
# 24 번째 이미지 저장중입니다=======
# 25 번째 이미지 저장중입니다=======
# 26 번째 이미지 저장중입니다=======
# 27 번째 이미지 저장중입니다=======
# 28 번째 이미지 저장중입니다=======
# 29 번째 이미지 저장중입니다=======
# 30 번째 이미지 저장중입니다=======
# 31 번째 이미지 저장중입니다=======
# 32 번째 이미지 저장중입니다=======
# 33 번째 이미지 저장중입니다=======
# 34 번째 이미지 저장중입니다=======
# 35 번째 이미지 저장중입니다=======
# 36 번째 이미지 저장중입니다=======
# 37 번째 이미지 저장중입니다=======
# 38 번째 이미지 저장중입니다=======
# 39 번째 이미지 저장중입니다=======
# 40 번째 이미지 저장중입니다=======
# 41 번째 이미지 저장중입니다=======
# 42 번째 이미지 저장중입니다=======
# 43 번째 이미지 저장중입니다=======
# 44 번째 이미지 저장중입니다=======
# 45 번째 이미지 저장중입니다=======
# 46 번째 이미지 저장중입니다=======
# 47 번째 이미지 저장중입니다=======
# 48 번째 이미지 저장중입니다=======
# 49 번째 이미지 저장중입니다=======
# 50 번째 이미지 저장중입니다=======
# 51 번째 이미지 저장중입니다=======
# 52 번째 이미지 저장중입니다=======
# 53 번째 이미지 저장중입니다=======
# 54 번째 이미지 저장중입니다=======
# 55 번째 이미지 저장중입니다=======
# 56 번째 이미지 저장중입니다=======
# 57 번째 이미지 저장중입니다=======
# 58 번째 이미지 저장중입니다=======
# 59 번째 이미지 저장중입니다=======
# 60 번째 이미지 저장중입니다=======
# 61 번째 이미지 저장중입니다=======
# 62 번째 이미지 저장중입니다=======
# 63 번째 이미지 저장중입니다=======
# 64 번째 이미지 저장중입니다=======
# 65 번째 이미지 저장중입니다=======
# 66 번째 이미지 저장중입니다=======
# 67 번째 이미지 저장중입니다=======
# 68 번째 이미지 저장중입니다=======
# 69 번째 이미지 저장중입니다=======
# 70 번째 이미지 저장중입니다=======
# 71 번째 이미지 저장중입니다=======
# 72 번째 이미지 저장중입니다=======
# 73 번째 이미지 저장중입니다=======
# 74 번째 이미지 저장중입니다=======
# 75 번째 이미지 저장중입니다=======
# 76 번째 이미지 저장중입니다=======
# 77 번째 이미지 저장중입니다=======
# 78 번째 이미지 저장중입니다=======
# 79 번째 이미지 저장중입니다=======
# 80 번째 이미지 저장중입니다=======
# 81 번째 이미지 저장중입니다=======
# 82 번째 이미지 저장중입니다=======
# 83 번째 이미지 저장중입니다=======
# 84 번째 이미지 저장중입니다=======
# 85 번째 이미지 저장중입니다=======
# 86 번째 이미지 저장중입니다=======
# 87 번째 이미지 저장중입니다=======
# 88 번째 이미지 저장중입니다=======
# 89 번째 이미지 저장중입니다=======
# 90 번째 이미지 저장중입니다=======
# 91 번째 이미지 저장중입니다=======
# 92 번째 이미지 저장중입니다=======
# 93 번째 이미지 저장중입니다=======
# 94 번째 이미지 저장중입니다=======
# 95 번째 이미지 저장중입니다=======
# 96 번째 이미지 저장중입니다=======
# 97 번째 이미지 저장중입니다=======
# 98 번째 이미지 저장중입니다=======
# 99 번째 이미지 저장중입니다=======
# 100 번째 이미지 저장중입니다=======

# %%
# Step 7. 요약 정보를 출력합니다                 
print("=" *70) 
print("총 저장 건수는 %s 건 입니다 " %file_no) 
print("파일 저장 경로: %s 입니다" %img_dir) 
print("=" *70) 
driver.close( )
# Out:
# ======================================================================
# 총 저장 건수는 100 건 입니다
# 파일 저장 경로: c:\py_temp\2026-03-08-23-50-14-데이터 입니다
# ======================================================================
