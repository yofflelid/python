# %%
# 구 주소 블로그 : https://blog.naver.com/junhyuk_abba/221286810022
# 신 주소 블로그 : https://blog.naver.com/suheeryu/221314766979

print("=" *80)
print(" 연습문제: 블로그  크롤러 : 네이버  블로그 정보 수집하기")
print("=" *80)

#Step 1. 필요한 모듈과 라이브러리를 로딩합니다.
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium import webdriver
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time
import pandas  as pd    
import math
import urllib.request
import urllib

#Step 2. 필요한 정보 입력받기
query_txt = input('1.정보를 수집할 키워드는 무엇입니까?(기본값:벚꽃여행): ')
if query_txt == '' :
    query_txt='벚꽃여행'
    
start_date = input('2.조회를 시작할 날짜를 입력하세요(기본값:2024-01-01) :')
if start_date == '' :
    start_date = '2024-01-01'
    
end_date = input('3.조회를 종료할 날짜를 입력하세요(기본값:2024-12-31): ')
if end_date == '' :
    end_date = '2024-12-31'

try:
    cnt = int(input('4.몇 건의 정보를 수집할까요?(기본값:10) :'))
except :
    cnt = 10

page_cnt = math.ceil( cnt / 30 )

f_dir = input("5.파일을 저장할 폴더명만 쓰세요(기본값:c:\\py_temp\\):")
if f_dir == '' :
    f_dir="c:\\py_temp\\"

# Step 3. 결과를 저장할 파일명을 지정하기
import os

n = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' %(n.tm_year, n.tm_mon, n.tm_mday, n.tm_hour, n.tm_min, n.tm_sec)   

os.makedirs(f_dir+'NAVER_blog'+'-'+s+'-'+query_txt)
 
ft_name = f_dir+'NAVER_blog'+'-'+s+'-'+query_txt+'\\'+'NAVER_blog'+'-'+s+'-'+query_txt+'.txt'
fc_name = f_dir+'NAVER_blog'+'-'+s+'-'+query_txt+'\\'+'NAVER_blog'+'-'+s+'-'+query_txt+'.csv'
fx_name = f_dir+'NAVER_blog'+'-'+s+'-'+query_txt+'\\'+'NAVER_blog'+'-'+s+'-'+query_txt+'.xlsx'    
print("\n")  

s_time = time.time( )

#Step 4. 검색어 입력한 후 검색하여 View로 이동하기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)

url = 'https://www.naver.com'
driver.get(url)
driver.maximize_window()
time.sleep(2)

element = driver.find_element(By.NAME,"query")
element.send_keys(query_txt)
element.submit()
time.sleep(2)

#Step 4. 아래의 블로그 링크를 선택합니다
driver.find_element(By.LINK_TEXT,"블로그").click()
time.sleep(1)

#Step 5. 정렬 버튼 클릭
driver.find_element(By.LINK_TEXT,'최신순').click()
time.sleep(1)

#Step 6 검색 옵션 버튼 클릭
driver.find_element(By.LINK_TEXT,'옵션').click()
time.sleep(1)

#Step 7. 직접입력 클릭
driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[1]/a[9]').click()
time.sleep(2)

# 조회 시작 날짜와 종료 날짜 선택 2024-01-01
start_date2 = start_date.split('-')
start_year = start_date2[0]
start_mon = str(int(start_date2[1])) #글자로 바꿔야 함 
start_day = str(int(start_date2[2]))

end_date2 = end_date.split('-')
end_year = end_date2[0]
end_mon = str(int(end_date2[1]))
end_day = str(int(end_date2[2]))

#시작 날짜 부분 클릭
driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[1]/span[1]/a').click()

#시작 년도 클릭
driver.find_element(By.LINK_TEXT,start_year).click()
time.sleep(1)

#시작 월의 값은 xpath 로 선택합니다 ~ link text도 가능할 듯 
if start_mon == '1' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[1]').click()
    time.sleep(1)
elif start_mon == '2' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[2]').click()
    time.sleep(1)
elif start_mon == '3' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[3]').click()
    time.sleep(1)
elif start_mon == '4' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[4]').click()
    time.sleep(1)
elif start_mon == '5' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[5]').click()
    time.sleep(1)
elif start_mon == '6' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[6]').click()
    time.sleep(1)
elif start_mon == '7' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[7]').click()
    time.sleep(1)
elif start_mon == '8' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[8]').click()
    time.sleep(1)
elif start_mon == '9' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[9]').click()
    time.sleep(1)
else :
    driver.find_element(By.LINK_TEXT, start_mon).click()
    time.sleep(1)

#시작일의 값도 xpath 값을 사용합니다.
if start_day == '1' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[1]').click()
    time.sleep(1)                 
elif start_day == '2' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[2]').click()
    time.sleep(1)
elif start_day == '3' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[3]').click()
    time.sleep(1)
elif start_day == '4' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[4]').click()
    time.sleep(1)
elif start_day == '5' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[5]').click()
    time.sleep(1)
elif start_day == '6' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[6]').click()
    time.sleep(1)
elif start_day == '7' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[7]').click()
    time.sleep(1)
elif start_day == '8' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[8]').click()
    time.sleep(1)
elif start_day == '9' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[9]').click()
    time.sleep(1)
else :
    driver.find_element(By.LINK_TEXT, start_day).click()
    time.sleep(1)

#종료 날짜 부분 클릭
driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[1]/span[3]/a').click()

#종료 년도 클릭
driver.find_element(By.LINK_TEXT,end_year).click()
time.sleep(1)  

#종료 월의 값은 xpath 로 선택합니다
if end_mon == '1' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[1]').click()
    time.sleep(1)
elif end_mon == '2' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[2]').click()
    time.sleep(1)
elif end_mon == '3' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[3]').click()
    time.sleep(1)
elif end_mon == '4' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[4]').click()
    time.sleep(1)
elif end_mon == '5' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[5]').click()
    time.sleep(1)
elif end_mon == '6' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[6]').click()
    time.sleep(1)
elif end_mon == '7' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[7]').click()
    time.sleep(1)
elif end_mon == '8' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[8]').click()
    time.sleep(1)
elif end_mon == '9' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[9]').click()
    time.sleep(1)
else :
    driver.find_element(By.LINK_TEXT, end_mon).click()
    time.sleep(1)

#종료일의 값도 xpath 값을 사용합니다.
if end_day == '1' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[1]').click()
    time.sleep(1)                 
elif end_day == '2' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[2]').click()
    time.sleep(1)
elif end_day == '3' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[3]').click()
    time.sleep(1)
elif end_day == '4' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[4]').click()
    time.sleep(1)
elif end_day == '5' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[5]').click()
    time.sleep(1)
elif end_day == '6' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[6]').click()
    time.sleep(1)
elif end_day == '7' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[7]').click()
    time.sleep(1)
elif end_day == '8' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[8]').click()
    time.sleep(1)
elif end_day == '9' :
    driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[9]').click()
    time.sleep(1)
else :
    driver.find_element(By.LINK_TEXT,end_day).click()
    time.sleep(1)

# 날짜 입력 후 적용 버튼 클릭        
driver.find_element(By.XPATH,'//*[@id="snb"]/div[2]/ul/li[2]/div/div[2]/div[3]/button').click()
time.sleep(1)

# Step 5. 검색 요청 건수만큼 화면 스크롤링 하기 ~ pyautogui도 가능
# 자동 스크롤다운 함수
def scroll_down(driver):
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
    time.sleep(3)

i = 1
while (i <= page_cnt+2):
    scroll_down(driver) 
    i += 1
    print('%s 페이지 정보를 추출하고 있으니 잠시만 기다려 주세요~~^^' %i)

# Step 6. 현재 조회된 목록에서 URL 주소를 추출하여 리스트 생성하기
url_all_list=[]    #조회할 블로그의 URL 정보 저장용 리스트

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
blog_list = soup.find('div','sds-comps-vertical-layout sds-comps-full-layout fds-ugc-single-intention-item-list-tab').find_all('div','sds-comps-vertical-layout sds-comps-full-layout qaKlZYnoGkFTJwXN64s8')

for a in blog_list :
    url_all_list.append( a.find('a')['href'] )

url_final_list=[]   # 수집할 블로그 리스트를 저장할 변수 ~ 네이버가 아닌게 있을 수도 있으니, 네이버인 것만 리스트에 저장 
no = 1
for c in url_all_list :    
    if c.split('/')[2] == 'blog.naver.com' :
        url_final_list.append(c)
        no += 1

        if no > cnt :
            break

d_no = 1
print('')
print('정보를 수집할 블로그 URL 주소는 아래와 같습니다~~~')
print('')
for d in url_final_list :   
    print(d_no,':',d)
    d_no += 1

driver.close()
print('')

#Step 7. 수집된 URL 주소에 접속하여 데이터 추출하기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)

blog_addr2 = []
w_name2 = []
w_date2 = []
blog_txt2 = []

no = 1   # 전체 게시글 번호용 변수

for blog_addr in url_final_list :            
    driver.get(blog_addr)
    driver.maximize_window()
    
    time.sleep(3)
    print("\n")
    print("텍스트 추출 시작 =================================================")
    print("\n")
    
    #try: 
    driver.switch_to.frame('mainFrame')
    #except:
    #    continue
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    addr_1 = soup.find('div','se-main-container')
    addr_2 = soup.find('div','post-area')
       
    
    print(" 블로그 데이터를 수집합니다==============" ) # 구조가 다를때는 이렇게 if문으로 해야 함
    if addr_1 :
        f = open(ft_name, 'a',encoding='UTF-8')
        print("=" *80)    
        print("1.블로그주소: ",blog_addr)
        blog_addr2.append(blog_addr)
        f.write("\n")
        f.write("블로그 데이터를 수집합니다=============="  + "\n")
        
        f.write("1.블로그 주소:"+blog_addr + "\n")
        
        writer = soup.select("div.blog2_container > span.writer")
        try :
            wname = writer[0].get_text().split('・')[0].replace('\n','').strip()   # 작성자 닉네임
        except IndexError :
            wname = " "
        else :
            wname = wname.replace("\n","")
        
        print("2.작성자 닉네임: ",wname )
        f.write("2.작성자 닉네임:" + wname + "\n")
        w_name2.append(wname)
        
        wdate = soup.select("div.blog2_container > span.se_publishDate.pcol2")
        try : 
            wdate = writer[0].get_text().split('・')[1].replace('\n','').strip()
        except IndexError :
            wdate = " "
        
        print("3.작성일자:",wdate)
        f.write("3.작성 일자:" + wdate + "\n")
        w_date2.append(wdate)
    
        # 본문내용
        print("4.본문내용:")
        f.write("4.블로그 내용:" +"\n")
        blog_txt_all = soup.find('div','se-main-container').find_all('div','se-component')
        for txt in blog_txt_all :
            # 블로그 내용 출력중에 UnicodeEncodeError: 'UCS-2' codec can't encode characters.. 라는
            # 에러가 나올 경우가 있다. 이럴 때를 대비해서 예외처리를 해야 한다
            try :
                print(txt.get_text().replace('\n',''))
            except UnicodeEncodeError :
                continue
    
            f.write(txt.get_text().replace('\n','') + "\n")
            blog_txt2.append(txt.get_text().replace('\n',''))
        
        f.close()                
    
#Step 8. xls 형태와 csv 형태로 저장하기
naver_blog = pd.DataFrame()
naver_blog['블로그주소']=pd.Series(blog_addr2)
naver_blog['작성자닉네임']=pd.Series(w_name2)
naver_blog['작성일자']=pd.Series(w_date2)
naver_blog['블로그내용']=pd.Series(blog_txt2)

# csv 형태로 저장하기
naver_blog.to_csv(fc_name,encoding="utf-8-sig",index=False)

# 엑셀 형태로 저장하기
naver_blog.to_excel(fx_name ,index=False,engine='openpyxl')

e_time = time.time( )
t_time = e_time - s_time


print("\n") 
print("=" *80)
print("총 소요시간은 %s 초 입니다 " %round(t_time,1))
print("파일 저장 완료: txt  파일명 : %s " %ft_name)
print("파일 저장 완료: csv  파일명 : %s " %fc_name)
print("파일 저장 완료: xlsx 파일명 : %s " %fx_name)
print("=" *80)

driver.close( )
# Out:
# ...
#  연습문제: 블로그  크롤러 : 네이버  블로그 정보 수집하기
# ...
# 1.정보를 수집할 키워드는 무엇입니까?(기본값:벚꽃여행):
# 2.조회를 시작할 날짜를 입력하세요(기본값:2024-01-01) :
# 3.조회를 종료할 날짜를 입력하세요(기본값:2024-12-31):
# 4.몇 건의 정보를 수집할까요?(기본값:10) :
# 5.파일을 저장할 폴더명만 쓰세요(기본값:c:\temp\):
# 2 페이지 정보를 추출하고 있으니 잠시만 기다려 주세요~~^^
# 3 페이지 정보를 추출하고 있으니 잠시만 기다려 주세요~~^^
# 4 페이지 정보를 추출하고 있으니 잠시만 기다려 주세요~~^^
#
# 정보를 수집할 블로그 URL 주소는 아래와 같습니다~~~
#
# 1 : https://blog.naver.com/alphabet2580
# 2 : https://blog.naver.com/dmswl_0349
# 3 : https://blog.naver.com/i_amnaye
# 4 : https://blog.naver.com/sohyunsojin
# 5 : https://blog.naver.com/yuno3a
# 6 : https://blog.naver.com/anorok
# 7 : https://blog.naver.com/daily_hyeon
# 8 : https://blog.naver.com/1msun
# 9 : https://blog.naver.com/joachyeon
# 10 : https://blog.naver.com/jhllxll
#
#
#
# 텍스트 추출 시작 =================================================
#
#
#  블로그 데이터를 수집합니다==============
# ...
# 1.블로그주소:  https://blog.naver.com/alphabet2580
# 2.작성자 닉네임:  김민
# 3.작성일자: 2026. 3. 8. 22:08
# 4.본문내용:
# ...

# %%
date = '2024-01-01'
#date.split('-')
int(date.split('-')[1]) 
# 날짜를 눌러야 하는데, 블로그 화면에는 1,2,3,... 이런식으로 나오니
# 앞에 0을 지워야 함
# Out:
# 1
