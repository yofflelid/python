# %% [markdown]
# # LAB 03 - 프로그램 흐름 제어 / 리스트 (1) ~ 2/9 (9/115)

# %% [markdown]
# ### 1. 프로그램 흐름 제어
# - 중첩 조건문 : if-if , for-if, for-for : i+증가량 < 반복종료값
#     - 짝홀수의 합
#     - 공배수 구하기
#     - 구구단
#     - 별 찍기 문제
# - 반복문 흐름제어: continue(조건 식으로 강제 이동), break(반복문 강제 종료)
#     - 주사위 던지기
# ### 2. 리스트의 이해
# - 리스트이름 = [값1, 값2, .. 값n] 0부터 일련번호(인덱스) 시작
#     - 서로 다른 종류(데이터 형)의 값들이 저장될 수 있다. 정수, 문자열 등 혼합 가능
#     - 인덱스 번호를 활용하여 값에 접근 가능 : 출력, 연산 등에 활용
#     - Error : 존재하지 않는 인덱스의 원소 출력/ 존재하지 않는 인덱스에 값을 할당할 경우
# - 리스트의 연산 : 리스트+리스트, 리스트*정수
#     - 2차원 리스트 : 행/열에 접근
#     - 가변 리스트 : 각 행마다 서로 다른 크기의 리스트 포함 가능
# ### 3. 인덱싱과 슬라이싱
# - 인덱스 번호를 사용하여 리스트의 원소에 접근하는 방법
#     - 정방향 0부터 / 역방향 -1부터
#     - [시작인덱스 : 끝인덱스] , 끝인덱스는 지정된 값 전까지를 의미한다. 끝인덱스-1 자리까지
# - 리스트의 슬라이싱
#     - [ :n] [n: ] [ : ]
#     - 원소의 교체 / 삭제 / 대입 / 확장/ 축소
# ### 4. 리스트의 원소 복사 : 깊은 복사와 얕은 복사
# - 일반 변수(불변객체: 숫자형, 문자열, 논리값) '=' 대입(=복사) (원본에 영향 X) ~ 깊은 복사
# - 연속성 자료형(가변객체: 리스트, 튜플)에 대한 '=' 참조(복사X) (원본에 영향 O) ~ 얕은 복사
#     - 원소를 하나하나 복사 (참조가 아닌 실질적인 복사를 하기 위함), (원본에 영향 X) ~ 깊은 복사
#     - [ : ]슬라이싱으로 리스트 전체, 일부를 다른 변수에 복사 , (원본에 영향X) ~ 깊은 복사
#     - copy() , 리스트 복사의 가장 표준적인 방법, (원본에 영향 X) ~ 깊은 복사
# https://wikidocs.net/16038
#
# ### 5. 리스트의 탐색 (1)  ; while
# - 리스트(튜플) 자체를 조건식으로 지정
#     - 원소 유무에 따라 True / False
# - 리스트에 포함 되어 있는지 확인 / 중복되어 있는지 확인
#     - in / not in
# - 리스트(튜플)의 길이(원소 수) 구하기
#     - len
# - while문을 사용한 리스트의 원소 탐색
#     - 반복문의 특성과 리스트 인덱스의 특성을 일치시킨다.
#     - 리스트 원소의 합계, 평균 구하기

# %% [markdown]
# ## 메모
# - 처음부터 교재를 보지 말고,
# 강의를 듣고, 확인하는 용도로 보기
# - 전 세계 개발자들이 프로그래밍 문제를 질문하고 답변을 받는 Q&A 플랫폼
# - https://stackoverflow.com/questions
# - error를 만들어보기
# - 변수는 변수인데, 객체 안에 있는 변수를 멤버 변수라고 한다.
# - 함수는 함수인데, 객체 안에 있는 함수를 메서드 라고 한다.
# - . ~의
# - 객체의 설계도 class ( 사람 dna )
# - 변수: 속성~ 정적인 명사 / 함수: 기능~ 동사적인 동사
# - 객체는 멤버변수와 메서드 안에 포함된다.
# - 내장함수 / 내장객체

# %% [markdown]
# ### 1. 프로그램 흐름 제어
# - 중첩 조건문 : if-if , for-if, for-for : i+증가량 < 반복종료값
#     - 짝홀수의 합
#     - 공배수 구하기
#     - 구구단
#     - 별 찍기 문제
# - 반복문 흐름제어: continue(조건 식으로 강제 이동), break(반복문 강제 종료)
#     - 주사위 던지기

# %%
point = int(input("점수를 입력하세요: "))

if point > 70:
    print("패스 입니다.")

    if point > 90:
        print("A입니다.")
    elif point > 80:
        print("B입니다.")
    else:
        print("C입니다.")
else: 
    print("패스하지 못했습니다.")
# Out:
# 패스하지 못했습니다.

# %%
# 충접 조건문 : 짝홀수의 합 
# 반복 수행 1회마다 조건을 판별한다. 
# 주로 반복문에서 설정되는 조건 값에 대한 검사를 수행한다. 

number = int(input("숫자를 입력하세요: "))

# 총 합(누적합)을 구하기 위해서는 반복문 전에 0으로 초기화 된 변수가 필요하다. 
# 반복문 안에서 조건문을 쓰는 이유 : 매 반복마다 i가 바뀌니까 그때그때 짝수인지 검사해야 함 
# 하나씩 검사 -> 맞는 통에 넣기 -> 계속 누적 

x = 0 
y = 0 

for i in range(1, number+1):            # -> 1~number까지 반복 수행 
    if i % 2 == 0 :                     # 2로 나눈 나머지가 0이면 짝수 
        print( i, "--> 짝수")
        x += i                          # x = x+i 
    else :                              # 그렇지 않으면 홀수 
        print(i, "--> 홀수")
        y += i

print("짝수들의 합: ", x)                # 2, 4, 6, 8, 10
print("홀수들의 합: ", y)                # 1, 3, 5, 7, 9
# Out:
# 1 --> 홀수
# 2 --> 짝수
# 3 --> 홀수
# 4 --> 짝수
# 5 --> 홀수
# 짝수들의 합:  6
# 홀수들의 합:  9

# %%
x = 0 
y = 0 

for i in range(1, number+1):            # -> 1~number까지 반복 수행 
    if i % 2 == 0 :                     # 2로 나눈 나머지가 0이면 짝수 
        print( i, "--> 짝수")
        
    else :                              # 그렇지 않으면 홀수 
        print(i, "--> 홀수")
       

print("짝수들의 합: ", x)
print("홀수들의 합: ", y)
# Out:
# 1 --> 홀수
# 2 --> 짝수
# 3 --> 홀수
# 4 --> 짝수
# 5 --> 홀수
# 6 --> 짝수
# 7 --> 홀수
# 8 --> 짝수
# 9 --> 홀수
# 10 --> 짝수
# 11 --> 홀수
# 12 --> 짝수
# 13 --> 홀수
# 14 --> 짝수
# 15 --> 홀수
# 16 --> 짝수
# 17 --> 홀수
# 18 --> 짝수
# 19 --> 홀수
# 20 --> 짝수
# 21 --> 홀수
# 22 --> 짝수
# 23 --> 홀수
# 24 --> 짝수
# 25 --> 홀수
# 26 --> 짝수
# 27 --> 홀수
# 28 --> 짝수
# 29 --> 홀수
# 30 --> 짝수
# 31 --> 홀수
# 32 --> 짝수
# 33 --> 홀수
# 34 --> 짝수
# 35 --> 홀수
# 36 --> 짝수
# 37 --> 홀수
# 38 --> 짝수
# 39 --> 홀수
# 40 --> 짝수
# 41 --> 홀수
# 42 --> 짝수
# 43 --> 홀수
# 44 --> 짝수
# 45 --> 홀수
# 짝수들의 합:  0
# 홀수들의 합:  0

# %%
# 충접 조건문 : 자주 사용되는 유형 ~ 반복 수행시 마지막 회차 생략하기 

for i in range(0,5) :
    print(i)
    # 조건 값이 마지막이 아닌 경우만 실행하도록 if 문 구성 
    if i + 1 < 5 :              # i + 증가량 < 반복종료값 
        print( "-----")
# Out:
# 0
# -----
# 1
# -----
# 2
# -----
# 3
# -----
# 4

# %%
# 중첩 조건문 : 공배수 구하기 for if 
# 1에서 100 사이의 수 중에서 3과 5의 공배수 출력하기 
# 그러면 나눴을 때, 나머지가 0이어야 겠군 
# 3과 5는 계속 쓸거니까, 변수로 지정? 해야겠군

x = 3
y = 5

for i in range(1,101) :
    if i % x == 1 and i % y == 0 :
        print(i)
# Out:
# 10
# 25
# 40
# 55
# 70
# 85
# 100

# %%
# 중첩 반복문 : 실행 과정 확인 
# 바깥의 부모 반복문이 1회차를 수행하는 동안 
# 안쪽의 자식 반복문이 매번 처음부터 다시 시작한다. 

for i in range(0,3) :
    print("i에 대한 반복 수행 시작 : i --> ", i) 

    for j in range(0,5) :
        print( "::: i =", i, ", j =", j)

    print("i에 대한 반복 수행 종료")

    if i + 1 < 3 :
        print("--------------")



# i 반복 시작
#    j 반복 시작
#        j 출력
#    j 반복 끝
#    i 종료 메시지 출력
#    조건 검사
#i 반복 끝 

#j는 i 안에 있기 때문에
#i가 한 번 바뀔 때마다
#j는 새로 시작하는 거야.
# Out:
# i에 대한 반복 수행 시작 : i -->  0
# ::: i = 0 , j = 0
# ::: i = 0 , j = 1
# ::: i = 0 , j = 2
# ::: i = 0 , j = 3
# ::: i = 0 , j = 4
# i에 대한 반복 수행 종료
# --------------
# i에 대한 반복 수행 시작 : i -->  1
# ::: i = 1 , j = 0
# ::: i = 1 , j = 1
# ::: i = 1 , j = 2
# ::: i = 1 , j = 3
# ::: i = 1 , j = 4
# i에 대한 반복 수행 종료
# --------------
# i에 대한 반복 수행 시작 : i -->  2
# ::: i = 2 , j = 0
# ::: i = 2 , j = 1
# ::: i = 2 , j = 2
# ::: i = 2 , j = 3
# ::: i = 2 , j = 4
# i에 대한 반복 수행 종료

# %%
# 중첩 반복문 : 구구단 
# 2단에서 3단으로 넘어가기 위해 1부터 9까지의 숫자가 반복되며 결과값을 생성한다. 
# 3단에서 4단으로 넘어가기 위해 다시 처음부터 1부터 9까지 반복된다. 

# i 의 변화 범위 2~9 
for i in range(2,10) :

    # i가 1 증가하는 동안 j의 값이 매번 1~9까지 새로 시작 

    for j in range(1,10) :
        k = i * j 
        print(i, "x", j, "=", k)

    if i +1 < 10 :
        print("-------------")
# Out:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# -------------
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# -------------
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# -------------
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# -------------
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# -------------
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# -------------
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# -------------
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# ...

# %%
# 중첩된 반복문에서 자식 반복문의 수행 범위를 동적으로 설정하는 문제 
# 별 찍기 문제 

# 반복문이 2중으로 중첩된 경우 
# 바깥쪽의 반복문이 행을 담당하고 안쪽의 반복문은 열을 담당한다. 

for i in range(0,5) :

    for j in range(0,3) :
    
        print(i, j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2
# 3 0
# 3 1
# 3 2
# 4 0
# 4 1
# 4 2

# %%
#실수 
for i in range(3):
    if i > 1:
        print(i)
#→ if 안인데 들여쓰기 안 함
# Out:
# 2

# %%
for i in range(0,5) :
    
    for j in range(0, i+1) :

        print( i, j )
# Out:
# 0 0
# 1 0
# 1 1
# 2 0
# 2 1
# 2 2
# 3 0
# 3 1
# 3 2
# 3 3
# 4 0
# 4 1
# 4 2
# 4 3
# 4 4

# %%
# 중첩 반복문 
# 별 찍기 문제 
# 중첩된 반복문에서 자식 반복문의 수행 범위를 동적으로 설정하는 문제

# 첫째 줄에는 별 1개, 둘째 줄에는 별 2개, n번째 줄에는 별 n개를 찍는 문제 

# 행은 5행, 열은 행이 증가함에 따라 반복 횟수가 1씩 증가 

# 행을 담당하는 반복문 
for i in range(0,5) :
    # 매 행마다 출력할 내용을 초기화 
    star = ""

    for j in range(0, i+1) :          #i+ 1 -1 행 만큼 출력 
        star += "*"

    print(star)
# Out:
# *
# **
# ***
# ****
# *****

# %%
# 반복문 흐름 제어 
# break 
# continue 
# 무한 루프

# %%
# 반복문 흐름 제어 
# 반복의 횟루를 가늠할 수 없을 때 의도적으로 무한루프를 설정하게 된다. 
# 이때 continue , break 명령으로 반복문 내에서의 흐름을 제어할 수 있다. 

# 일단 처음에 변수 지정하고, 
# while 문으로 True일때 돌리고, 
# break할 지점 정하고 

# 1부터 9까지, 홀수만 보고 싶다. 
y = 0 

while True :            # True/False는 항상 첫글자가 대문자 
    y += 1 

    if y % 2 == 0 : 
        continue        #조건식으로 강제 이동 

    if y > 10 :
        break           # 반복문 강제로 종료 

    print("Hello Python::", y)
# Out:
# Hello Python:: 1
# Hello Python:: 3
# Hello Python:: 5
# Hello Python:: 7
# Hello Python:: 9

# %%
# 주사위 던지기 
# 두 개의 주사위를 던졌을 때, 
# 눈의 합이 6이 되는 모든 경우의 수를 출력하고 
# 경우의 수는 총 몇가지 인지 출력하시오. 

# 변수가 i , j 
# 눈의 합이 6 이니까, 범위는 1, 6+1 =7
# 경우의 수가 몇가지 인지 궁금한거니까, for for if 가 부합하면, 1씩 증가  

# 경우의 수가 몇가지 인지 궁금 
count = 0           # 조건에 부합하는 경우의 수를 카운트 하기 위한 변수 

for i in range(1,7) :           # 첫 번째 주사위 
    for j in range(1,7) :       # 두 번째 주사위 
        if i + j == 6 :         # 두 눈의 합이 6이 되는 경우 
            count += 1          # 조건이 맞는 경우 카운트 1 증가 
            print(i, j)


print("경우의 수 : ", count)
# Out:
# 1 5
# 2 4
# 3 3
# 4 2
# 5 1
# 경우의 수 :  5

# %% [markdown]
# ### 2. 리스트의 이해
# - 리스트이름 = [값1, 값2, .. 값n] 0부터 일련번호(인덱스) 시작
#     - 서로 다른 종류(데이터 형)의 값들이 저장될 수 있다. 정수, 문자열 등 혼합 가능
#     - 인덱스 번호를 활용하여 값에 접근 가능 : 출력, 연산 등에 활용
#     - Error : 존재하지 않는 인덱스의 원소 출력/ 존재하지 않는 인덱스에 값을 할당할 경우
# - 리스트의 연산 : 리스트+리스트, 리스트*정수
#     - 2차원 리스트 : 행/열에 접근
#     - 가변 리스트 : 각 행마다 서로 다른 크기의 리스트 포함 가능

# %%
# 2. 리스트의 이해 
## 리스트 정의하기

# 같은 종류의 원소를 갖는 리스트와 서로 다른 종류의 원소를 갖는 리스트 

# 5명의 학생에 대한 성적 나열 --> 정수형 원소만 갖는 리스트
grade = [98, 82, 73, 64, 100]
print(grade)
# Out:
# [98, 82, 73, 64, 100]

# %%
#
names = ["철수", "영희", "나영", "민식", "호영"]
print(names)
# Out:
# ['철수', '영희', '나영', '민식', '호영']

# %%
# 서로 다른 자료형들을 함께 사용 가능 
student = ["철수", 17, 162.4, 68.5, "남자", True]
print(student)
# Out:
# ['철수', 17, 162.4, 68.5, '남자', True]

# %%
# 2. 리스트의 이해 
## 리스트 원소에 접근하기 

cheolsu = [75, 82, 91]

print(cheolsu[0])

#
a = cheolsu[1]
print(a)

#
print( 100 + cheolsu[2])
# Out:
# 75
# 82
# 191

# %%
# 2. 리스트의 이해 
## 리스트 원소에 접근하기 
### 에러 

# IndexError: list index out of range

#items = [10, 20, 30]
#print( items[5])

# %%
#IndexError: list assignment index out of range

#items = [100, 200, 300]
#items[3] = 300 
#print(items)

# %%
# 인덱스 번호를 통한 리스트 원소값 사용
# 원소를 통해 접근한다는 특성만 이해하면 일반 변수처럼 사용 가능함 

# 인덱스 번호를 통해 각 원소에 접근할 수 있다. 
items = [10, 20, 30]
print(items[0])
print(items[1])
print(items[2])
# Out:
# 10
# 20
# 30

# %%
#값의 변경 

mydata = [100, 200, 300]
print( mydata) 

mydata[0] = 0
mydata[1] = mydata[1] -150 
mydata[2] //= 3
print(mydata)
# Out:
# [100, 200, 300]
# [0, 50, 100]

# %%
# 리스트의 덧셈 
# 두 개의 리스트를 더하면 , 연결된 새로운 리스트가 생성된다.

a = [1,2,3]
b = [4,5]
c = a + b           # new !!! 
print(c)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 리스트와 정수의 곱셈 
# 곱해진 만큼 원소가 반복되는 새로운 리스트가 생성된다.

d = [10, 20, 30]
e = d * 3          # new !!! 
print(e)
# Out:
# [10, 20, 30, 10, 20, 30, 10, 20, 30]

# %%
# 리스트의 연산 

list1 = [10, 20, 30]
list2 = [40, 50, 60]
print(list1)
print(list2)
# Out:
# [10, 20, 30]
# [40, 50, 60]

# %%
# 리스트끼리의 덧셈은 단순 병합 

list3 = list1 + list2
print(list3)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
# 

list4 = list1 * 5
print(list4)
# Out:
# [10, 20, 30, 10, 20, 30, 10, 20, 30, 10, 20, 30, 10, 20, 30]

# %%
# error

#TypeError: can only concatenate list (not "int") to list
#print(list1 + 10 )

#TypeError: can only concatenate list (not "str") to list
#print(list1 + "hi")

#TypeError: can't multiply sequence by non-int of type 'list'
#print(list1 * list2)

# %%
# 2차원 리스트의 정의 

# 
stud1 = ["철수", 98]
stud2 = ["영희", 82]
stud3 = ["나영", 73]

#
studentGroup = [stud1, stud2, stud3]
print(studentGroup)
# Out:
# [['철수', 98], ['영희', 82], ['나영', 73]]

# %%
# 2차원 리스트의 일괄 생성 
# -> 바깥의 리스트에 속한 원소들은 행을 구성하고, 
# 안쪽의 리스트에 속한 원소들은 열을 구성한다. 

# , 

studentGroup2 = [
    ["민식", 64, 172.3] ,
    ["호영", 100, 175.8] ,
    ["철민", 89, 168.7]
]

print(studentGroup2)
# Out:
# [['민식', 64, 172.3], ['호영', 100, 175.8], ['철민', 89, 168.7]]

# %%
# 2차원 리스트의 행에 접근하기 

# 
student = [["민식", 64, 172.3], ["호영", 100, 175.8], ["철민", 89, 168.7]]

#
print(student[0])

#
print(student[1])

#
print(student[2])
# Out:
# ['민식', 64, 172.3]
# ['호영', 100, 175.8]
# ['철민', 89, 168.7]

# %%
# 2차원 리스트의 열에 접근하기 

# 
student = [["민식", 64, 172.3], ["호영", 100, 175.8], ["철민", 89, 168.7]]

print("이름: ",student[0][0] , "몸무게: ",student[0][1], "키: ",student[0][2] )
print("이름: ",student[1][0] , "몸무게: ",student[1][1], "키: ",student[1][2] )
print("이름: ",student[2][0] , "몸무게: ",student[2][1], "키: ",student[2][2] )
# Out:
# 이름:  민식 몸무게:  64 키:  172.3
# 이름:  호영 몸무게:  100 키:  175.8
# 이름:  철민 몸무게:  89 키:  168.7

# %%
# 가변 리스트 

# 각 행마다 열의 수가 다른 리스트 형태로 표현한 상품 목록 

items = [
    ["티셔츠", "M", "빨강", 15000] , 
    ["청바지", 32, "청색", 45000, "리바이스"],
    ["운동화", 270, "검정", 60000, "나이키", "가죽"]
]

print("상품: ", items[0][0], "사이즈: ", str(items[0][1]), ", 색상: ", 
      items[0][2], ", 가격: " +str(items[0][3]))

print("상품: ", items[1][0], "사이즈: ", str(items[1][1]), ", 색상: ", 
      items[1][2], ", 가격: " +str(items[1][3]), ", 브랜드: ", items[1][4])

print("상품: ", items[2][0], "사이즈: ", str(items[2][1]), ", 색상: ", 
      items[2][2], ", 가격: " +str(items[2][3]), ", 브랜드: ", items[2][4],
        ", 재질: "+ items[2][5])
# Out:
# 상품:  티셔츠 사이즈:  M , 색상:  빨강 , 가격: 15000
# 상품:  청바지 사이즈:  32 , 색상:  청색 , 가격: 45000 , 브랜드:  리바이스
# 상품:  운동화 사이즈:  270 , 색상:  검정 , 가격: 60000 , 브랜드:  나이키 , 재질: 가죽

# %% [markdown]
# ### 3. 인덱싱과 슬라이싱
# - 인덱스 번호를 사용하여 리스트의 원소에 접근하는 방법
#     - 정방향 0부터 / 역방향 -1부터
#     - [시작인덱스 : 끝인덱스] , 끝인덱스는 지정된 값 전까지를 의미한다. 끝인덱스-1 자리까지
# - 리스트의 슬라이싱
#     - [ :n] [n: ] [ : ]
#     - 원소의 교체 / 삭제 / 대입 / 확장/ 축소

# %%
# 3. 인덱싱과 슬라이싱 
# 리스트의 인덱싱
# 정방향 0 / 역방향 -1 
mylist = [10, 20, 30]
print(mylist[1])
print(mylist[-1])
# Out:
# 20
# 30

# %%
first = mylist[0] 
print(first)
# Out:
# 10

# %%
mylist[1] = 200 
print(mylist)
# Out:
# [10, 200, 30]

# %%
## 리스트의 인덱싱 
# [시작인덱스 : 끝인덱스]
# 시작은 포함, 끝은 포함하지 않음 

mylist = [10, 20, 30, 40, 50]

print(mylist[1:4])

print(mylist[-4:-1])

print(mylist[1:-1])
# Out:
# [20, 30, 40]
# [20, 30, 40]
# [20, 30, 40]

# %%
## 리스트의 슬라이싱 

### 리스트의 구간 설정 방법 

mylist = [ 60, 70, 80, 90 ]

print(mylist[1:3])

print(mylist[1:-2])
# Out:
# [70, 80]
# [70]

# %%
## 리스트의 슬라이싱 

### 시작 인덱스를 지정하지 않은 슬라이싱 [ :n ] 처음부터 n번째 까지 

mylist = [ 60, 70, 80, 90 ]

print(mylist[:4]) 

print(mylist[:-1])
# Out:
# [60, 70, 80, 90]
# [60, 70, 80]

# %%
## 리스트 슬라이싱 

# 종료 인덱스를 지정하지 않은 슬라이싱 [ n : ] n번째 부터 끝까지 

mylist = [ 60, 70, 80, 90 ]

print(mylist[1: ])

print(mylist[-4: ])
# Out:
# [70, 80, 90]
# [60, 70, 80, 90]

# %%
## 리스트 슬라이싱

# 시작위치와 종료위치를 모두 지정하지 않는 경우 [ : ]처음부터 끝까지 슬라이싱


mylist = [ 10, 20, 30, 40, 50 ]

print(mylist[:])
# Out:
# [10, 20, 30, 40, 50]

# %%
# 리스트 슬라이싱 

# n번째 원소부터 끝까지 
# 처음부터 n번째 원소까지 
# 모든 원소 
mylist = [ 10, 20, 30, 40, 50 ]


print(mylist[3: ])
print(mylist[ :3])
print(mylist[ : ])
# Out:
# [40, 50]
# [10, 20, 30]
# [10, 20, 30, 40, 50]

# %%
# 슬라이싱을 활용한 리스트의 원소 교체 및 삭제 

# 슬라이싱으로 지정된 원소의 수와 같은 길이를 갖는 리스트 타입 

foo = [1, 2, 3, 4, 5]

#
foo[1:4] = [20, 30, 40]
print(foo)
# Out:
# [1, 20, 30, 40, 5]

# %%
# 슬라이싱으로 지정된 범위에 빈 리스트를 대입 

bar = [11, 22, 33, 44, 55]

#
bar[1 : 4] = [  ]
print(bar)
# Out:
# [11, 55]

# %%
# 리스트의 확장, 축소 

# 지정된 범위보다 크기가 큰 리스트 대입 

mylist[1:4] = [100, 200, 300, 400]
print(mylist)
# Out:
# [10, 100, 200, 300, 400, 50]

# %%
# 지정된 범위보다 크기가 작은 리스트 대입 
mylist = [10, 20, 30, 40, 50]

mylist[1:4] = [100, 200]
print(mylist)
# Out:
# [10, 100, 200, 50]

# %%
#
hello = [6, 7, 8, 9, 10]

#
hello[1:4] = [100, 200, 300, 400, 500, 600, 700]
print(hello)
# Out:
# [6, 100, 200, 300, 400, 500, 600, 700, 10]

# %%
world = [11, 12, 13, 14, 15]

# 
world[1:4] = [1000, 2000]
print(world)
# Out:
# [11, 1000, 2000, 15]

# %% [markdown]
# ### 4. 리스트의 원소 복사 : 깊은 복사와 얕은 복사
# - 일반 변수(숫자형, 문자열, 논리값) '=' 대입(=복사) (원본에 영향 X) ~ 깊은 복사
# - 연속성 자료형(리스트, 튜플)에 대한 '=' 참조(복사X) (원본에 영향 O) ~ 얕은 복사
#     - 원소를 하나하나 복사 (참조가 아닌 실질적인 복사를 하기 위함), (원본에 영향 X) ~ 깊은 복사
#     - [ : ]슬라이싱으로 리스트 전체, 일부를 다른 변수에 복사 , (원본에 영향X) ~ 깊은 복사
#     - copy() , 리스트 복사의 가장 표준적인 방법, (원본에 영향 X) ~ 깊은 복사
#
#
# 💡 1️⃣ 메모리 효율성
# 모든 대입이 깊은 복사라면?
# b = a
# 할 때마다 데이터를 전부 복제해야 함.
# 대용량 데이터일 경우
# 👉 성능 폭발
# 👉 메모리 낭비
# 그래서 기본은 참조 공유
#
# 💡 2️⃣ 객체 지향 철학
# 파이썬은 “객체 기반 언어”
# 변수는 객체를 가리키는 이름표.
# 객체를 공유하는 게 자연스러운 모델.

# %%
# 4. 리스트의 원소 복사 

#먼저 전제: 파이썬은 “값”이 아니라 “객체의 주소”를 다룬다

#파이썬에서 변수는 데이터를 직접 저장하지 않아요.
#👉 객체(object)를 가리키는 이름표입니다.

# 일반 변수끼리의 대입은 값을 복사하는 기능을 한다. 
# 복사본에 저장되어 있는 값을 다른 값으로 변경하더라도 원본은 영향을 받지 않는다.  
a = 100
b = a
print(a)
print(b)

# a와 b는 같은 리스트를 가지게 된다. 
print(id(a))
print(id(b))
# Out:
# 100
# 100
# 140732300165128
# 140732300165128

# %%
# 복사본은 변경하더라도 원본에는 변화가 없다.(반대의 경우도 마찬가지)
a = 100
b = a
b = 200
print(a)
print(b)

print(id(a))
print(id(b))

#이건 “100을 수정”하는 게 아니라
#👉 b가 새로운 객체 200을 가리키게 되는 것

#📌 정수는 immutable (불변 객체) 이기 때문입니다.

#정수는 내부 값을 바꾸는 게 아니라
#항상 새 객체를 생성합니다.

#그래서 “값이 복사된 것처럼 보이는 것”입니다.
# Out:
# 100
# 200
# 140732300165128
# 140732300168328

# %%
# 3️⃣ 리스트는 왜 다를까?
# 
# 얕은 복사 (Shallow Copy)
# ✔ 개념

# 겉에 있는 껍데기만 복사
# 안쪽에 있는 객체(특히 리스트 안의 리스트)는 공유 
# 단순 대입은 복사가 아니다

# 객체의 참조 --> 리스트, 딕셔너리 등 

foo = [1, 2, 3]
bar = foo 
print(foo)
print(bar)

#→ id가 같으면 같은 객체
print(id(foo))
print(id(bar))
# Out:
# [1, 2, 3]
# [1, 2, 3]
# 1551577057280
# 1551577057280

# %%
# 참조된 복사본을 변경하면 원본도 함께 변경됨. (반대의 경우도 마찬가지) 


#👉 리스트 객체 내부 값을 수정한 것

#리스트는 mutable (가변 객체) 이기 때문에
#객체 자체를 수정합니다.

bar[1] = 20
print(foo)
print(bar)

print(id(foo))
print(id(bar))
# Out:
# [1, 20, 3]
# [1, 20, 3]
# 1551577057280
# 1551577057280

# %%
# 연속성 자료형의 고전적인 깊은 복사 방법
# 각 원소의 개별 복사 
# 참조가 아닌 실질적인 복사로 처리하려면 각각의 원소를 하나씩 복사해야 한다. 

# 1. 새로운 리스트 객체 생성
# 2. 각 원소의 값을 복사
# 3. 결과적으로 다른 객체 완성

#리스트 복사 
# -> 같은 길이의 리스트를 만들고 각 원소를 일일이 복사함 
bar = [1, 2, 3]
cp1 = [0, 0, 0]
cp1[0] = bar[0]
cp1[1] = bar[1]
cp1[2] = bar[2]

# -> 복사본은 변경하더라도 원본에 변화 없음 
cp1[2] = 1000
print(bar)
print(cp1)

print(id(bar))
print(id(cp1))
# Out:
# [1, 2, 3]
# [1, 2, 1000]
# 1551577452352
# 1551577138240

# %% [markdown]
# - 4️⃣ 핵심 개념 정리
# - 자료형	변경 가능?	대입 시 동작
# - int	❌ 불변	새 객체 생성
# - float	❌ 불변	새 객체 생성
# - str	❌ 불변	새 객체 생성
# - list	✅ 가변	객체 공유
# - dict	✅ 가변	객체 공유
# - set	✅ 가변	객체 공유

# %%
# 슬라이싱을 활용한 깊은 복사 
# 슬라이싱으로 리스트 전체 혹은 일부를 다른 변수에 복사할 경우 
# 원본에 영향을 주지 않고 복사본을 변경할 수 있다. 

#슬라이싱을 활용한 방법
hello = [100, 200, 300]
cp2 = hello[:]

# -> 복사본을 변경하더라도 원본에 영향이 없다. 
print(hello)
print(cp2)
# Out:
# [100, 200, 300]
# [100, 200, 300]

# %%
# 리스트에 포함된 함수를 사용한 깊은 복사 
# 리스트 객체의 copy() 메서드(=함수)를 활용한 리스트의 복사 
# 리스트 복사의 가장 표준적인 방법 
# 슬라이싱과 마찬가지로 원본에 영향을 주지 않고 복사본을 변경할 수 있다. 


# 리스트 객체의 함수를 사용하는 방법 
world = ["hello", "python", "world"]
cp3 = world.copy()

# -> 복사본을 변경하더라도 원본에 영향이 없다. 
cp3 = "nice"
print(world)
print(cp3)

#cp3 = "nice" 는
#리스트를 수정한 것이 아니라
#👉 cp3라는 이름표를
#👉 새로운 문자열 객체에 다시 연결한 것

#처음
#cp3 ──▶ ["hello","python","world"]

#이후
#cp3 ──▶ "nice"
#world ──▶ ["hello","python","world"]
# Out:
# ['hello', 'python', 'world']
# nice

# %%
# 튜플의 이해 
# 리스트와 동일한 특성을 갖는 자료구조
# 소괄호를 사용하여 원소를 나열한다. 

# 5 명의 학생에 대한 성적 나열 
grade = (98, 82, 73, 64, 100)
print(grade)
# Out:
# (98, 82, 73, 64, 100)

# %%
#
names = ("철수", "영희", "나영", "민식", "호영")
print(names)
# Out:
# ('철수', '영희', '나영', '민식', '호영')

# %%
# 자료형에 대한 혼합 사용도 가능함 
stud1 = ("철수", 98)
print(stud1)
# Out:
# ('철수', 98)

# %%
#
print(stud1[0])
print(stud1[1])
# Out:
# 철수
# 98

# %% [markdown]
# 튜플의 이해
#
# 1️⃣ 리스트(List)란 무엇인가?
# ✅ 정의
#
# 리스트는 여러 개의 값을 순서대로 저장하는 자료구조야.
# 그리고 가장 중요한 특징:
#
# 🔥 값을 변경할 수 있다 (Mutable)
# 이걸 가변 객체(mutable object) 라고 부른다.
#
# 리스트의 특징 정리
# 대괄호 [ ] 사용
# 순서가 있다 (인덱스 존재)
# 값 변경 가능
# 원소 추가/삭제 가능
# 실무에서 가장 많이 사용
#
# 2️⃣ 튜플(Tuple)이란 무엇인가?
# ✅ 정의
#
# 튜플은 리스트와 거의 비슷하지만,
# 🔥 한번 만들면 값을 바꿀 수 없다 (Immutable)
#
# 이걸 불변 객체(immutable object) 라고 부른다.

# %% [markdown]
# 케글
# 공공데이터
# 크롤링
#
# 대학원 해외기업 공기업 대기업 중소기업 ~ 공공데이터
# 실제 운영되는 서비스 데이터 ~ 마케팅 ~ 크롤링 데이터
#
# 잘하는것. 중요하다 생각하는 것.
#
# 자기소개 ~ 관심분야 , 어디쪽으로 취업, 어떤 데이터에 관심
# 언제 모이고, 공부할지,
# 앞에 3개월을 잘 보내기 ~ 시행착오를 줄이기
#
# 할 줄 아는걸 하고,
# 공모전
#
# 단체로 해보고,
# 종강하고 한 달 이내에 개인포트폴리오 만들어보기

# %%
# 튜플의 이해 
#
# 튜플은 한번 생성하고 나면 원소의 값을 수정할 수 없다. : 그래서 활용을 거의 하지 않는다. 

#내부 값을 수정할 수 없음
#복사 필요성 거의 없음
#안전한 데이터 구조

# 값의 변경 --> 튜플은 값의 변경이 불가능하므로 에러 
#TypeError: 'tuple' object does not support item assignment

# stud1[0] = "철호"

# %%
#
# 
a , b = ["python", "bigdata"]

print(a)
print(b)
# Out:
# python
# bigdata

# %%
#
a, b =("python", "bigdata")

print(a) 
print(b)
# Out:
# python
# bigdata

# %%
# 
# 선언된 변수의 수와 리스트의 원소 수가 다르면 에러가 발생한다. 
# ValueError: too many values to unpack (expected 3)
# a , b, c = [10, 20, 30, 40]

# %%
# 함수 리턴 값의 구조분해
# 함수가 두 개 이상의 결과를 리턴해야 하는 경우 리스트로 묶어서 리턴할 수 있다. 
# 리스트를 리턴 받는 경우 구조분해가 가능하다. 

# divmod()는 실제로 파이썬에 내장되어 있는 함수 
def divmod(a, b) :
    # 몫과 나머지를 리스트로 묶어서 반환하는 함수 
    return [a // b , a % b]

# 함수 호출 -> 리턴 결과는 리스트 이다. 
result = divmod(7,3) 
print(result) 


# 리턴 결과를 구조분해로 받기 
x, y = divmod(7, 3) 
print("몫: ", x, ", 나머지: ", y)
# Out:
# [2, 1]
# 몫:  2 , 나머지:  1

# %% [markdown]
# - 1. 변수는 값을 담는 상자가 아니다.
#     - 파이썬에서 변수는 객체를 가리키는 이름표입니다.
#
# - 2. 객체의 핵심 구분: Mutable vs Immutable
#     - 구분	예시	                     수정 가능?	대입 시 특징
#     - Immutable	int, float, str, tuple	❌	새 객체 생성
#     - Mutable	list, dict, set	✅	객체 내부 수정 가능
#
# - =        → 참조 공유
# - [:]      → 얕은 복사
# - deepcopy → 완전 복사

# %% [markdown]
# ① 참조 공유 (복사 아님)
# b = a
#
#
# 같은 객체를 가리킴
#
# 한쪽 수정 → 다른 쪽도 변경
#
# ② 얕은 복사 (Shallow Copy)
# b = a.copy()
# b = a[:]
#
# 특징
#
# 겉 리스트는 새로 생성
#
# 내부 객체는 공유
#
# 구조 (중첩 리스트일 때)
# - a ──▶ [ ──▶ [1,2]
#     - ──▶ [3,4] ]
#
# - b ──▶ [ ──▶ [1,2]
#     - ──▶ [3,4] ]
#
#
# 겉은 다름
# 안쪽은 동일
#
# ③ 깊은 복사 (Deep Copy)
# import copy
# b = copy.deepcopy(a)
#
#
# 내부 객체까지 전부 새로 생성
#
# 완전 독립
#
# 4️⃣ 슬라이싱의 정확한 의미
# b = a[:]
#
#
# ✔ 얕은 복사
# ✔ 리스트 전체 또는 일부 복사 가능
#
# a[1:3]   # 부분 복사
#
#
# 📌 주의: 중첩 구조에서는 깊은 복사가 아니다.

# %% [markdown]
# 📌 최종 구별법 — 실전 체크리스트
#
# 코드 작성 전에 스스로 물어보세요:
#
# 1️⃣ 이 자료형은 mutable인가?
#
# → list, dict, set이면 주의
#
# 2️⃣ = 을 사용하고 있는가?
#
# → 참조 공유일 가능성 높음
#
# 3️⃣ 내부 값을 수정할 예정인가?
#
# → copy 고려
#
# 4️⃣ 중첩 구조인가?
#
# → deepcopy 고려
#
# 5️⃣ 반복문에서 같은 객체를 저장하는가?
#
# → 반드시 copy()

# %% [markdown]
# ### 5. 리스트의 탐색 (1)  ; while
# - 리스트(튜플) 자체를 조건식으로 지정
#     - 원소 유무에 따라 True / False
# - 리스트에 포함 되어 있는지 확인 / 중복되어 있는지 확인
#     - in / not in
# - 리스트(튜플)의 길이(원소 수) 구하기
#     - len
# - while문을 사용한 리스트의 원소 탐색
#     - 반복문의 특성과 리스트 인덱스의 특성을 일치시킨다.
#     - 리스트 원소의 합계, 평균 구하기

# %%
# 리스트(튜플) 자체를 조건식으로 지정 (1) 
# 리스트나 튜플 자체를 조건식으로 지정할 경우, 
# 원소의 유무에 따라 True, False가 판정된다. 

#원소가 하나라도 포함된 경우 True  
mylist = [10, 20, 30]

if mylist: 
    print("원소가 포함됨")
else:
    print("원소가 포함되지 않음")
# Out:
# 원소가 포함됨

# %%
# 리스트(튜플) 자체를 조건식으로 지정 (2)
# 원소가 포함되지 않은 리스트나 튜플을 조건식으로 지정할 경우 False로 판정된다. 

mylist = [ ]

if mylist: 
    print("원소가 포함됨")
else: 
    print("원소가 포함되지 않음")
# Out:
# 원소가 포함되지 않음

# %% [markdown]
# 1️⃣ in 의 본질
# ✔ 의미
# 어떤 값이 컨테이너(리스트, 튜플, 문자열 등) 안에 포함되어 있는지 확인하는 연산자
#
# ✔ 결과
# 항상 True / False (논리값) 로 나온다.
#
# 2️⃣ 그럼 not in은 뭐냐?
# ✔ 의미
# 포함되어 있지 않으면 True
#
# 즉, not in = in의 결과를 뒤집는다.
#
# - 비교표로 정리
# - 표현	                뜻	결과
# - A in B	A가 B에 있다	True
# - A not in B	A가 B에 없다	True
#
# ✔ 올바른 사고 순서
# 1. in 먼저 판단
# 2. 그 다음에 not으로 뒤집기
#
# 조건식 볼 때 이렇게 생각해:
#
# 1단계: 포함되었는가?
# 2단계: 부정인가?
# 3단계: 그래서 최종 True인가 False인가?
#
# ex
# 1) 특정 값 제거
# if value not in allowed_values:
#     continue
# 2) 이상치 제거
# if country not in ["Korea", "USA", "Japan"]:
#     print("기타 국가")
# 3) 문자열에도 사용 가능
# "abc" in "abcdef"

# %%
# 리스트에 포함되어 있는지 확인 (1)
# in / not in 연산자 사용하기 


# 변수 in 리스트 
# 변수가 리스트 안에 포함되어 있는 경우, 연산 결과가 True 

# 변수 not in 리스트 
# 변수가 리스트 안에 포함되어 있지 않은 경우, 연산 결과가 False 

mylist = [5, 7, 1, 9]
target = 7 

#
find = target in mylist 
print(find)

#
not_find = target not in mylist
print(not_find)
# Out:
# True
# False

# %%
# 리스트에 포함되어 있는지 확인 (2)
# in / not in 연산자 사용하기 

# 조건문에서 in 연산자를 사용하여 , 
# 새로운 아이디가 기존 회원 목록과 중복되는지 확인하기 

# 기존에 있는 아이디 리스트 
user_id_list = ["mike", "tom", "jane"]

# 
user_id = input("아이디를 입력하세요: ")

# 입력받은 아이디가 이미 사용중인지 확인 
# 입력받은 아이디가, 기존에 있는 아이디 리스트에 있는지 확인 
if user_id in user_id_list :
    print("죄송합니다. 해당 아이디는 사용중입니다.")
else:
    print("사용 가능한 아이디 입니다. ")
# Out:
# 죄송합니다. 해당 아이디는 사용중입니다.

# %%
# 리스트에 포함되어 있는지 확인 (3)

# 조건문에서 not in 연산자를 사용하여 
# 새로 가입하는 아이디가 기존 회원 목록과 중복되는지 확인하기 

# 입력값 tom은 기존 목록과 중복되므로 
# False 
# 그러므로, else절이 실행된다. 

user_id_list = ["mike", "tom", "jane"]

#
user_id = input("아이디를 입력하세요: ")

#
if user_id not in user_id_list :
    print("사용 가능한 아이디 입니다. ")
else: 
    print("죄송합니다. 해당 아이디는 사용 중입니다. ")
# Out:
# 죄송합니다. 해당 아이디는 사용 중입니다.

# %% [markdown]
# 왜 len()을 쓰는가?
# len(mylist)
#
# len = length = 길이
#
# 이걸 쓰는 이유는:
# 리스트 길이가 바뀌어도 코드 수정 필요 없음
# 범용 코드 작성 가능
# 함수화 가능
#
# 하드코딩 ❌
# while i < 5:
#
# 유연한 코드 ⭕
# while i < len(mylist):

# %%
# 리스트의 길이(=원소 수) 구하기 

# len() 은 파라미터로 전달되는 데이터의 길이를 반환한다. 

# 리스트의 원소 수 
mylist = [10, 20, 30, 40, 50 ]
mylen = len(mylist)
print(mylen)
# Out:
# 5

# %%
# 튜플의 경우도 동일하다. 
mytuple = (10, 20, 30, 40, 50)
mylen = len(mytuple)
print(mylen)
# Out:
# 5

# %% [markdown]
# while 조건:
#     실행코드
#
# 1. 조건을 확인한다
# 2. 참이면 코드 실행
# 3. 다시 조건으로 올라간다
# 4. 거짓이면 종료
#
# 합계 구하는 알고리즘의 본질
# 컴퓨터는 자동으로 누적하지 않는다.
#
# 사람은 “다 더해”라고 말하면 되지만
# 컴퓨터는 반드시:
# 저장 공간 만들고
# 초기값 0 넣고
# 하나씩 더하고
# 다시 저장
# 이 과정을 수행한다.

# %%
# 1차원 리스트 탐색
# 반복문의 인덱스 변수를 활용한 리스트 탐색 

mylist = [1,2,3]
i = 0

while i < len(mylist):
    print(mylist[i])
    i += 1


# list[i] ❌
# list는 파이썬 내장 자료형 이름이야.
# 리스트를 저장한 변수가 아니야.
i=0 
while i < len([1,2,3]): 
    # i 값이 순차적으로 1씩 증가하므로, 자연스럽게 리스트의 각 원소를 탐색하게 된다. 
    print(list[i])
    i +=1
# Out:
# list[0]
# list[1]
# list[2]
# 1
# 2
# 3

# %%
# while문을 사용한 리스트의 원소 탐색 

# 반복문의 특성과 리스트의 인덱스의 특성을 일치시킨다. 
# 반복문의 조건값이 0부터 시작하고 
# 리스트의 길이보다 작은 동안 1씩 증가하도록 구성하면 
# 리스트의 인덱스와 동일한 특성을 갖는다. 

mylist = [10, 20, 30, 40, 50]
size = len(mylist)
i = 0

# 인덱스가 전체 원소 수 보다 작은 동안 반복

while i < size :
    print(mylist[i])
    i += 1
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
# 리스트 원소의 합계, 평균 구하기 

# 리스트의 모든 원소를 탐색하며 합계 구하기 

score = [92, 88, 76, 82]
subject = len(score)
i = 0 
total_score = 0

# 인덱스가 과목수 보다 작은 동안 반복 
while i < subject:
    total_score += score[i]
    i += 1

mean_score = total_score / subject

print( "총점", total_score, "/ 평균:", mean_score)
# Out:
# 총점 338 / 평균: 84.5
